# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import os
import pickle
from sentences import *
from DCS import *
from utilities import *
from IPython.display import display

# %%
df_ri_pf = pd.read_csv('extras/replace_new@pf.csv', header=None, names=['sktLemma', 'dcsLemma', 'file', 'chunk'])
df_ri_10to20 = pd.read_csv('extras/replace_new@skt.csv', header=None, names=['sktLemma', 'dcsLemma', 'file', 'chunk'])
df_ri_upd = pd.read_csv('extras/replace_new@upd.csv', header=None, names=['sktLemma', 'dcsLemma', 'file', 'chunk'])

# %%
ix = 0
fx = df_ri_pf.loc[ix, 'file']
display(df_ri_pf[df_ri_pf['file'] == fx])
fn = '%d.p' % fx
fp = '../TextSegmentation/Pickle_Files//' + fn
print(fn, fp)
skt, dcs = loadSentence(fn, fp)
# Out:
#   sktLemma dcsLemma    file  chunk                                       path
# 0      Suc     Suci  315608      1  ../TextSegmentation/Pickle_Files/315608.p
# 315608.p ../TextSegmentation/Pickle_Files//315608.p

# %%
SeeSentence(skt)
# Out:
# SKT ANALYZE
# ---------------
# kftAYjaliH  Sucir BUtvA vAgvidAM pravaraH  praBum
# Analyzing  kftA\xf1jaliḥ
# 0 :  kftA\xf1jalis ['kftA\\xf1jal'] [{'noun': ['nom. sg. m.', 'nom. sg. f.']}]
# 0 :  kfta ['kf'] [{'verb': ['inj. [4] md. sg. 3', 'inj. [1] md. sg. 3']}]
# 0 :  kftA ['kfta', 'kf'] [{'noun': ['nom. sg. f.']}, {'verb': ['pp.']}]
# 0 :  kfta ['kfta', 'kf'] [{'compound': ['iic.']}, {'verb': ['pp.']}]
# 3 :  a\xf1jalis ['a\\xf1jal'] [{'noun': ['nom. sg. m.']}]
# 3 :  a\xf1jalis ['a\\xf1jal'] [{'noun': ['nom. sg. f.']}]
# Analyzing  Suciḥ
# 0 :  Sucis ['Suc'] [{'noun': ['nom. sg. m.', 'nom. sg. f.']}]
# Analyzing  BUtvA_vAgvidAm
# 0 :  BUtvA ['BU'] [{'indeclinable': ['abs.']}]
# 9 :  vidAm ['vid'] [{'noun': ['g. pl. m.', 'g. pl. n.', 'g. pl. f.']}]
# 9 :  vidAm ['vid'] [{'noun': ['g. pl. m.', 'g. pl. n.', 'g. pl. f.']}]
# 9 :  vi ['vI'] [{'compound': ['iic.']}]
# 11 :  dAm ['da'] [{'noun': ['acc. sg. f.']}]
# 6 :  vAgvi ['vAgvn'] [{'compound': ['iic.']}]
# 6 :  vAk ['vAc'] [{'compound': ['iic.']}]
# 6 :  vAk ['vAc'] [{'noun': ['nom. sg. f.']}]
# Analyzing  pravaraḥ
# 0 :  pravaras ['pravara', 'pravara', 'pravara'] [{'noun': ['nom. sg. m.']}, {'noun': ['nom. sg. m.']}, {'noun': ['nom. sg. m.']}]
# Analyzing  praBum
# 0 :  praBum ['praBu'] [{'noun': ['acc. sg. m.']}]

# %%
SeeDCS(dcs)
# Out:
# DCS ANALYZE
# ---------------
# kftAYjaliH  Sucir BUtvA vAgvidAM pravaraH  praBum
# [['kṛtāñjali'], ['śuci'], ['bhū'], ['vāc', 'vid'], ['pravara'], ['prabhu']]
# Lemmas: ['kftAYjali', 'Suci', 'BU', 'vAc', 'vid', 'pravara', 'praBu']
# [['29'], ['29'], ['-230'], ['3', '159'], ['29'], ['69']]

# %%
goodFileDict = pickle.load(open('mergedGood_v5.p', 'rb'))

# %%
df_ri_pf['path'] = df_ri_pf.apply(lambda row: '../TextSegmentation/Pickle_Files/%d.p' % row['file'], axis=1)
df_ri_10to20['path'] = df_ri_10to20.apply(lambda row: '../TextSegmentation/corrected_10to20/%d.p' % row['file'], axis=1)
df_ri_upd['path'] = df_ri_upd.apply(lambda row: '../TextSegmentation/Updated Pickles/%d.p' % row['file'], axis=1)

# %%
frames = [df_ri_pf, df_ri_10to20, df_ri_upd]
df_ri = pd.concat(frames)

# %%
print(len(df_ri['file'].unique()))
df_ri
# Out:
# 157804
#       sktLemma   dcsLemma    file  chunk  \
# 0          Suc       Suci  315608      1
# 1          sam       sami  140135      1
# 2        vcAra     vicAra  333703      7
# 3          ptf       pitf  358530      3
# 4           fz        fzi  107907      0
# 5          rAS       rASi   95131      1
# 6         rAtr      rAtri  111125      3
# 7        nvAsa     nivAsa  337816      2
# 8         mtra      mitra  318357      1
# 9     sOmadatt  sOmadatti  383279      0
# 10         bal       bali  346616      2
# 11       nvftt    nivftti  123406      0
# 12     vSezaRa   viSezaRa   68370      1
# 13     vyAvftt   vyAvftti   68370      2
# 14     saMyogn   saMyogin   68370      3
# 15      tvarta    tvarita   54418      0
# 16          ha        iha  130851      0
# 17        vzRu      vizRu  130851      3
# 18        vnda      vinda  389178      0
# 19    sudakzRa  sudakziRa  389178      2
# 20     bahuvDa   bahuviDa  395705      1
# 21         dvz       dviz  394377      0
# 22       aYjal     aYjali   53667      3
# 23        smft      smfti  345108      3
# 24        prya      priya  103301      5
# 25      kalApn    kalApin   74803      1
# 26      SKaRqn   SiKaRqin   74803      3
# 27        tyAd     ityAdi   65757      1
# 28         ptf       pitf  387198      3
# 29         vnA       vinA  340770      2
# ...        ...        ...     ...    ...
# 1255        ct        cit    1840      3
# 1256      vSva      viSva    1840      4
# 1257        Ad        Adi    1840      8
# 1258        Bd        Bid   30965      3
# 1259     suzra     suzira   35038      2
# 1260        vD       viDi   38079     12
# 1261   kuRqaln   kuRqalin    1668      0
# 1262       hta       hita   25842      0
# 1263     AtTya     AtiTya   28645      0
# 1264      vpra      vipra   28645      2
# 1265        vD       viDi   10636      8
# 1266      rocs      rocis   15329      0
# 1267      Sakt      Sakti   30388      0
# 1268        dv        div   20444      9
# 1269        dv        div   20444     14
# 1270       kzp       kzip   32042      2
# 1271     ndrya    indriya   33975      1
# 1272    ctraka    citraka   10488      0
# 1273        vD       viDi    1993      1
# 1274      aBDA      aBiDA    1993     14
# 1275       kzp       kzip   31617      3
# 1276     ndrya    indriya    7119      2
# 1277      ctta      citta   12170      4
# 1278     nmtta    nimitta    8381      1
# 1279      lNgn     liNgin   26026      0
# 1280        fz        fzi   19297      2
# 1281      tTam      itTam    6863      0
# 1282      lNgn     liNgin   19039      1
# 1283       sta       sita   30425      1
# 1284  durnvAra  durnivAra   34477      1
#
#                                              path
# 0       ../TextSegmentation/Pickle_Files/315608.p
# 1       ../TextSegmentation/Pickle_Files/140135.p
# 2       ../TextSegmentation/Pickle_Files/333703.p
# 3       ../TextSegmentation/Pickle_Files/358530.p
# 4       ../TextSegmentation/Pickle_Files/107907.p
# 5        ../TextSegmentation/Pickle_Files/95131.p
# 6       ../TextSegmentation/Pickle_Files/111125.p
# 7       ../TextSegmentation/Pickle_Files/337816.p
# 8       ../TextSegmentation/Pickle_Files/318357.p
# 9       ../TextSegmentation/Pickle_Files/383279.p
# 10      ../TextSegmentation/Pickle_Files/346616.p
# 11      ../TextSegmentation/Pickle_Files/123406.p
# 12       ../TextSegmentation/Pickle_Files/68370.p
# 13       ../TextSegmentation/Pickle_Files/68370.p
# 14       ../TextSegmentation/Pickle_Files/68370.p
# 15       ../TextSegmentation/Pickle_Files/54418.p
# 16      ../TextSegmentation/Pickle_Files/130851.p
# 17      ../TextSegmentation/Pickle_Files/130851.p
# 18      ../TextSegmentation/Pickle_Files/389178.p
# 19      ../TextSegmentation/Pickle_Files/389178.p
# 20      ../TextSegmentation/Pickle_Files/395705.p
# 21      ../TextSegmentation/Pickle_Files/394377.p
# 22       ../TextSegmentation/Pickle_Files/53667.p
# 23      ../TextSegmentation/Pickle_Files/345108.p
# 24      ../TextSegmentation/Pickle_Files/103301.p
# 25       ../TextSegmentation/Pickle_Files/74803.p
# 26       ../TextSegmentation/Pickle_Files/74803.p
# 27       ../TextSegmentation/Pickle_Files/65757.p
# 28      ../TextSegmentation/Pickle_Files/387198.p
# 29      ../TextSegmentation/Pickle_Files/340770.p
# ...                                           ...
# 1255   ../TextSegmentation/Updated Pickles/1840.p
# 1256   ../TextSegmentation/Updated Pickles/1840.p
# 1257   ../TextSegmentation/Updated Pickles/1840.p
# 1258  ../TextSegmentation/Updated Pickles/30965.p
# 1259  ../TextSegmentation/Updated Pickles/35038.p
# 1260  ../TextSegmentation/Updated Pickles/38079.p
# 1261   ../TextSegmentation/Updated Pickles/1668.p
# 1262  ../TextSegmentation/Updated Pickles/25842.p
# 1263  ../TextSegmentation/Updated Pickles/28645.p
# 1264  ../TextSegmentation/Updated Pickles/28645.p
# 1265  ../TextSegmentation/Updated Pickles/10636.p
# 1266  ../TextSegmentation/Updated Pickles/15329.p
# 1267  ../TextSegmentation/Updated Pickles/30388.p
# 1268  ../TextSegmentation/Updated Pickles/20444.p
# 1269  ../TextSegmentation/Updated Pickles/20444.p
# 1270  ../TextSegmentation/Updated Pickles/32042.p
# 1271  ../TextSegmentation/Updated Pickles/33975.p
# 1272  ../TextSegmentation/Updated Pickles/10488.p
# 1273   ../TextSegmentation/Updated Pickles/1993.p
# 1274   ../TextSegmentation/Updated Pickles/1993.p
# 1275  ../TextSegmentation/Updated Pickles/31617.p
# 1276   ../TextSegmentation/Updated Pickles/7119.p
# 1277  ../TextSegmentation/Updated Pickles/12170.p
# 1278   ../TextSegmentation/Updated Pickles/8381.p
# 1279  ../TextSegmentation/Updated Pickles/26026.p
# 1280  ../TextSegmentation/Updated Pickles/19297.p
# 1281   ../TextSegmentation/Updated Pickles/6863.p
# 1282  ../TextSegmentation/Updated Pickles/19039.p
# 1283  ../TextSegmentation/Updated Pickles/30425.p
# 1284  ../TextSegmentation/Updated Pickles/34477.p
#
# [213134 rows x 5 columns]

# %%
ix = 100
# fx = 336116
fx = df_ri.loc[ix, 'file']
fr = df_ri[df_ri['file'] == fx]

display(df_ri[df_ri['file'] == fx])
# skt, dcs = loadSentence(fn, fp)

# %%
files = df_ri['file'].unique()
files
# Out:
# array([315608, 140135, 333703, ...,  26026,  30425,  34477])

# %%
missing1Dict = pickle.load(open('missing1Dict.p', 'rb'))

# %%
# Out:
# 31560.800000000003

# %%
counter = 0
tCounter = 0
for fx in files:
    fn = '%d.p' % fx
    df_occur = df_ri[df_ri['file'] == fx]
    slemmas = {}   
    
    fp = df_occur.iloc[0].loc['path']
    try:
        skt, dcs = loadSentence(fn, fp)
    except IndexError:
        continue
    if(len(skt.chunk) != len(dcs.lemmas)):
        continue
#     display(df_occur)
    #=====================================================================
    # FOLLOWING BLOCK OF CODE FIXES SKT OBJECTS WITH THE REPLACE 'i' ISSUE
    #=====================================================================
    for ci in df_occur['chunk']:
        slemmas[ci] = {}
        for index, row in df_occur.loc[df_occur['chunk'] == ci].iterrows():
            slemmas[ci][row['sktLemma']] = row['dcsLemma']
#         print(slemmas)
        chunk = skt.chunk[ci]
        for pos in chunk.chunk_words.keys():
            for wsi in range(len(chunk.chunk_words[pos])):
                ws = chunk.chunk_words[pos][wsi]
                for li in range(len(ws.lemmas)):
                    lemma = ws.lemmas[li]
                    if lemma in slemmas[ci]:
#                         print('Yes', lemma)
                        skt.chunk[ci].chunk_words[pos][wsi].lemmas[li] = slemmas[ci][lemma]

    # NOW CHECK FULL COVERAGE
    goodFlag = FullCoverage(skt, dcs)
#     print(goodFlag)
    if goodFlag:
        counter += 1
        pickle.dump(skt, open('../TextSegmentation/CompatSKT/%d.p2' % fx, 'wb'))
    tCounter += 1
    if(tCounter % 200 == 0):
        print('Chekpoint', counter, 'of', tCounter)
# Out:
# Chekpoint 37 of 200

# %%
newList = os.listdir('../TextSegmentation/CompatSKT/')
f = newList[30]
print(f[:-1:])
s2, d2 = loadSentence_nopre(f[:-1:], '../TextSegmentation/CompatSKT/' + f)
SeeSentence(s2)
SeeDCS(d2)
# Out:
# 66029.p
# SKT ANALYZE
# ---------------
# mAMsahetor api mfgAn vihArArTaM ca DanvinaH
# Analyzing  mAMsahetoḥ
# 0 :  mAMsa ['mAMsa'] [{'compound': ['iic.']}]
# 0 :  mAMs ['mAMs'] [{'compound': ['iic.']}]
# 0 :  mAMs ['mAMs'] [{'noun': ['acc. sg. n.', 'nom. sg. n.']}]
# 0 :  mAm ['mad'] [{'noun': ['acc. sg. *']}]
# 0 :  mA ['mA'] [{'indeclinable': ['part.']}]
# 0 :  mA ['mad'] [{'noun': ['acc. sg. *']}]
# 1 :  aMsa ['aMsa'] [{'compound': ['iic.']}]
# 3 :  sa ['tad'] [{'noun': ['nom. sg. m.']}]
# 4 :  a ['a'] [{'compound': ['iic.']}]
# 5 :  hetos ['hetu'] [{'noun': ['abl. sg. m.']}]
# 5 :  hetos ['hetu'] [{'noun': ['g. sg. f.', 'abl. sg. f.']}]
# Analyzing  api
# 0 :  api ['api'] [{'indeclinable': ['conj.', 'prep.']}]
# Analyzing  mfgAn
# 0 :  mfgAn ['mfga'] [{'noun': ['acc. pl. m.']}]
# Analyzing  vihArArTam
# 0 :  vihAra ['vihAra'] [{'compound': ['iic.']}]
# 0 :  viha ['vha'] [{'compound': ['iic.']}]
# 3 :  ara ['ara'] [{'compound': ['iic.']}]
# 3 :  Ara ['Ara'] [{'compound': ['iic.']}]
# 3 :  arA ['ara'] [{'noun': ['nom. sg. f.']}]
# 3 :  ArA ['Ara'] [{'noun': ['nom. sg. f.']}]
# 5 :  arTam ['arTa'] [{'noun': ['acc. sg. m.']}]
# 5 :  ArTam ['ArTa'] [{'noun': ['acc. sg. m.', 'acc. sg. n.', 'nom. sg. n.']}]
# 5 :  arTam ['arTa'] [{'noun': ['acc. sg. n.', 'nom. sg. n.']}]
# Analyzing  ca
# 0 :  ca ['ca'] [{'indeclinable': ['conj.']}]
# Analyzing  Danvinaḥ
# 0 :  Danvinas ['Danvin'] [{'noun': ['acc. pl. m.', 'nom. pl. m.', 'g. sg. m.', 'abl. sg. m.', 'g. sg. n.', 'abl. sg. n.']}]
# 0 :  Danvinas ['Danvin'] [{'noun': ['voc. pl. m.']}]
# 0 :  Danvi ['Danvin'] [{'noun': ['acc. sg. n.', 'nom. sg. n.']}]
# 0 :  Danu ['Danu'] [{'compound': ['iic.']}]
# 0 :  DanU ['Danu'] [{'compound': ['iic.']}]
# 0 :  DanU ['Danu'] [{'noun': ['acc. du. m.', 'nom. du. m.']}]
# 4 :  inas ['na'] [{'noun': ['nom. sg. m.']}]
# 5 :  nas ['mad'] [{'noun': ['g. pl. *', 'dat. pl. *', 'acc. pl. *']}]
#
# DCS ANALYZE
# ---------------
# mAMsahetor api mfgAn vihArArTaM ca DanvinaH
# [['māṃsa', 'hetu'], ['api'], ['mṛga'], ['vihāra', 'artha'], ['ca'], ['dhanvin']]
# Lemmas: ['mAMsa', 'hetu', 'api', 'mfga', 'vihAra', 'arTa', 'ca', 'Danvin']
# [['3', '129'], ['2'], ['79'], ['3', '69'], ['2'], ['39']]
