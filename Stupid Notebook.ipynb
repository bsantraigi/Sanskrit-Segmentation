# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas
import pandas as pd
import numpy as np
import gensim
import csv

import pickle
from utilities import *
from sentences import *
from DCS import *
import os
# Out:
# ERROR (theano.sandbox.cuda): nvcc compiler not found on $PATH. Check your nvcc installation and try again.

# %%
co_ocMat = pickle.load(open('extras/all_dcs_lemmas_matrix.p', 'rb'))
cngMat = pickle.load(open('extras/same_cng_matrix.p', 'rb'))
dcsLemmas = pickleFixLoad('extras/unique_dcs_lemmas.p')
cng_ordered_list = pickle.load(open('extras/list_of_uniq_cngs.p', 'rb'))

# %%
# from collections import defaultdict
# def AutoID():
#     aid = -1
#     while(True):
#         aid += 1
#         yield aid

# auto_id = AutoID()

# indexDict = defaultdict(lambda: next(auto_id))
# temp = [indexDict[x] for x in dcsLemmas]
# pickle.dump(dict(indexDict), open('dcsLemma2index.p', 'wb'))

# indexDictCng = defaultdict(lambda: next(auto_id))
# temp = [indexDictCng[x] for x in cng_ordered_list]
# pickle.dump(dict(indexDictCng), open('cng2index_dict.p', 'wb'))

# %%
from SktWsegRWR_utf8 import *
from AlgoTestFactory import *
# Out:
# Current folder contains:  44790  Files

# %%
def runMultiProcess(prCount, upto, method, savePath):
    print("Using", prCount, "Processes")
    filePerProcess = upto/prCount
    testerProcesses = [None]*prCount
    for thId in range(0,prCount):
        testerProcesses[thId] = AlgoTestFactory(
            [int(thId*filePerProcess), int((thId + 1)*filePerProcess)], 
            processID = thId, method=method, storeAccuracies=False, savePath = savePath)
        testerProcesses[thId].start()

    for p in testerProcesses:
        p.join()

# %%
runMultiProcess(10, 20, Method.word2vec, 'w2v_1_june')
# Out:
# Using 10 Processes
# Using word2vec
# Using word2vec
# Using word2vec
# Using word2vec
# Using word2vec
# Using word2vec
# Using word2vec
# Using word2vec
# Using word2vec
# Using word2vec
# Process Finished (accuracies not saved to disk)
# 42.857142857142854
# Process Finished (accuracies not saved to disk)
# 0.0
# 60.0
# Process Finished (accuracies not saved to disk)
# 23.076923076923077
# Process Finished (accuracies not saved to disk)
# 28.571428571428573
# 50.0
# Process Finished (accuracies not saved to disk)
# Process Finished (accuracies not saved to disk)
# 42.857142857142854
# 0.0
# Process Finished (accuracies not saved to disk)
# 28.571428571428573
# 7.6923076923076925
# Process Finished (accuracies not saved to disk)
# Process Finished (accuracies not saved to disk)
# 13.333333333333334
# Process Finished (accuracies not saved to disk)

# %%
runMultiProcess(1, 2, Method.type2type, 't2t_1_june')
# Out:
# Using 1 Processes
# Using type2type
# Process AlgoTestFactory-39:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/bishal/Documents/summer project/TxSeg_Summer/AlgoTestFactory.py", line 75, in run
#     result = self.algo.predict(sentenceObj, dcsObj)
#   File "/home/bishal/Documents/summer project/TxSeg_Summer/SktWsegRWR_utf8.py", line 162, in predict
#     TransitionMat = self.probModels.get_cng2cng_mat(cngList)
#   File "/home/bishal/Documents/summer project/TxSeg_Summer/ProbModels.py", line 29, in get_cng2cng_mat
#     cngIndexList = list(map(lambda x:cng2index_dict[str(x)], cngList))
#   File "/home/bishal/Documents/summer project/TxSeg_Summer/ProbModels.py", line 29, in <lambda>
#     cngIndexList = list(map(lambda x:cng2index_dict[str(x)], cngList))
# KeyError: 'none'

# %%
runMultiProcess(10, 20, Method.word2word, 'w2w_1_june')
# Out:
# Using 10 Processes
# Using word2word
# Using word2word
# Using word2word
# Using word2word
# Using word2word
# Using word2word
# Using word2word
# 60.0
# Process Finished (accuracies not saved to disk)
# Using word2word
# 42.857142857142854
# Using word2word
# Process Finished (accuracies not saved to disk)
# Process Finished (accuracies not saved to disk)
# Using word2word0.0
# Process Finished (accuracies not saved to disk)
#
# 14.285714285714286
# Process Finished (accuracies not saved to disk)
# 50.0
# 23.076923076923077
# Process Finished (accuracies not saved to disk)
# 42.857142857142854
# 7.6923076923076925
# Process Finished (accuracies not saved to disk)
# 33.333333333333336
# 28.571428571428573
# Process Finished (accuracies not saved to disk)
# Process Finished (accuracies not saved to disk)
# 0.0
# Process Finished (accuracies not saved to disk)

# %%
from sentences import *

# %%
sentencePath = '../TextSegmentation/Pickles/'
sentenceObj = pickleFixLoad(sentencePath + '14265.p')

# %%
SeeSentence(sentenceObj)
# Out:
# anena mantreRa sahasrajaptena kavitvaM karoti nAtra saMdehaH
# Analyzing  anena
# 0 :  anena ['ayam'] [{'noun': ['i. sg. m.', 'i. sg. n.']}]
# Analyzing  mantreRa
# 0 :  mantreá¹a ['mantra'] [{'noun': ['i. sg. m.', 'i. sg. n.']}]
# Analyzing  sahasrajaptena
# 0 :  sahasra ['sahasra'] [{'compound': ['iic.']}]
# 11 :  ina ['na'] [{'noun': ['voc. sg. m.', 'voc. sg. n.']}]
# 12 :  na ['na'] [{'indeclinable': ['part.']}]
# 7 :  japtena ['jap'] [{'noun': ['i. sg. n.', 'i. sg. m.'], 'verbform': ['"SKTMW93.html#H_jap"'], 'verb': [['pp.']]}]
# 7 :  japta ['jap'] [{'verbform': ['"SKTMW93.html#H_jap"'], 'compound': ['iic.'], 'verb': [['pp.']]}]
# 7 :  japtÄ ['jap'] [{'noun': ['nom. sg. f.'], 'verbform': ['"SKTMW93.html#H_jap"'], 'verb': [['pp.']]}]
# 7 :  japte ['jap'] [{'noun': ['acc. du. f.', 'nom. du. f.', 'acc. du. n.', 'nom. du. n.', 'loc. sg. n.', 'loc. sg. m.'], 'verbform': ['"SKTMW93.html#H_jap"'], 'verb': [['pp.']]}]
# Analyzing  kavitvam
# 0 :  kavitvam ['kavtva'] [{'noun': ['acc. sg. n.', 'nom. sg. n.']}]
# 0 :  kavi ['kav'] [{'compound': ['iic.']}]
# 0 :  ka ['ka_1'] [{'compound': ['iic.']}]
# 2 :  vi ['vÄ«_2'] [{'noun': ['acc. sg. n.', 'nom. sg. n.']}]
# 2 :  vi ['vÄ«_2'] [{'compound': ['iic.']}]
# 4 :  tvam ['-tva'] [{'noun': ['acc. sg. n.', 'nom. sg. n.']}]
# 4 :  tvam ['yuá¹£mad'] [{'noun': ['nom. sg. *']}]
# Analyzing  karoti
# 0 :  karoti ['ká¹\x9b_1'] [{'verb': ['pr. [8] ac. sg. 3']}]
# Analyzing  nAtra
# 0 :  na ['na'] [{'indeclinable': ['part.']}]
# 1 :  atra ['atra_1'] [{'undetermined': ['adv.']}]
# Analyzing  sandehaḥ
# 0 :  sandehas ['sandeha'] [{'noun': ['nom. sg. m.']}]
# 0 :  san ['sat', 'as_1'] [{'noun': ['nom. sg. m.']}, {'verb': ['ppr. [2] ac.']}]
# 3 :  dehas ['deha'] [{'noun': ['nom. sg. m.']}]

# %%
import math
start = 0
finish = 0
for i in range(0, int(math.log2(420000)) + 1):
    start = finish
    finish = min(math.pow(2, i+1), 420000)
    print("nohup python FilterGood.py {0} {1} ../TextSegmentation/Pickle_Files/ &".format(int(start), int(finish)))
    
    
start = 0
finish = 0
for i in range(0, int(math.log2(420000)) + 1):
    start = finish
    finish = min(math.pow(2, i+1), 420000)
    print("nohup python FilterGood.py {0} {1} ../TextSegmentation/corrected_10to20/ &".format(int(start), int(finish)))
# Out:
# nohup python FilterGood.py 0 2 ../TextSegmentation/Pickle_Files/ &
# nohup python FilterGood.py 2 4 ../TextSegmentation/Pickle_Files/ &
# nohup python FilterGood.py 4 8 ../TextSegmentation/Pickle_Files/ &
# nohup python FilterGood.py 8 16 ../TextSegmentation/Pickle_Files/ &
# nohup python FilterGood.py 16 32 ../TextSegmentation/Pickle_Files/ &
# nohup python FilterGood.py 32 64 ../TextSegmentation/Pickle_Files/ &
# nohup python FilterGood.py 64 128 ../TextSegmentation/Pickle_Files/ &
# nohup python FilterGood.py 128 256 ../TextSegmentation/Pickle_Files/ &
# nohup python FilterGood.py 256 512 ../TextSegmentation/Pickle_Files/ &
# nohup python FilterGood.py 512 1024 ../TextSegmentation/Pickle_Files/ &
# nohup python FilterGood.py 1024 2048 ../TextSegmentation/Pickle_Files/ &
# nohup python FilterGood.py 2048 4096 ../TextSegmentation/Pickle_Files/ &
# nohup python FilterGood.py 4096 8192 ../TextSegmentation/Pickle_Files/ &
# nohup python FilterGood.py 8192 16384 ../TextSegmentation/Pickle_Files/ &
# nohup python FilterGood.py 16384 32768 ../TextSegmentation/Pickle_Files/ &
# nohup python FilterGood.py 32768 65536 ../TextSegmentation/Pickle_Files/ &
# nohup python FilterGood.py 65536 131072 ../TextSegmentation/Pickle_Files/ &
# nohup python FilterGood.py 131072 262144 ../TextSegmentation/Pickle_Files/ &
# nohup python FilterGood.py 262144 420000 ../TextSegmentation/Pickle_Files/ &
# nohup python FilterGood.py 0 2 ../TextSegmentation/corrected_10to20/ &
# nohup python FilterGood.py 2 4 ../TextSegmentation/corrected_10to20/ &
# nohup python FilterGood.py 4 8 ../TextSegmentation/corrected_10to20/ &
# nohup python FilterGood.py 8 16 ../TextSegmentation/corrected_10to20/ &
# nohup python FilterGood.py 16 32 ../TextSegmentation/corrected_10to20/ &
# nohup python FilterGood.py 32 64 ../TextSegmentation/corrected_10to20/ &
# nohup python FilterGood.py 64 128 ../TextSegmentation/corrected_10to20/ &
# nohup python FilterGood.py 128 256 ../TextSegmentation/corrected_10to20/ &
# nohup python FilterGood.py 256 512 ../TextSegmentation/corrected_10to20/ &
# nohup python FilterGood.py 512 1024 ../TextSegmentation/corrected_10to20/ &
# nohup python FilterGood.py 1024 2048 ../TextSegmentation/corrected_10to20/ &
# nohup python FilterGood.py 2048 4096 ../TextSegmentation/corrected_10to20/ &
# nohup python FilterGood.py 4096 8192 ../TextSegmentation/corrected_10to20/ &
# nohup python FilterGood.py 8192 16384 ../TextSegmentation/corrected_10to20/ &
# nohup python FilterGood.py 16384 32768 ../TextSegmentation/corrected_10to20/ &
# nohup python FilterGood.py 32768 65536 ../TextSegmentation/corrected_10to20/ &
# nohup python FilterGood.py 65536 131072 ../TextSegmentation/corrected_10to20/ &
# nohup python FilterGood.py 131072 262144 ../TextSegmentation/corrected_10to20/ &
# nohup python FilterGood.py 262144 420000 ../TextSegmentation/corrected_10to20/ &

# %%
df_pf1 = pd.read_csv('extras/pvbnhi@pf.csv', header=None, names=['file', 'miss', 'miss2'])
df_pf2 = pd.read_csv('extras/pvbnhi@skt.csv', header=None, names=['file', 'miss', 'miss2'])
df_pf3 = pd.read_csv('extras/pvbnhi@upd.csv', header=None, names=['file', 'miss', 'miss2'])

# df_pf1['miss'] = df_pf1[df_pf1['miss'] != 'Incomplete chunk']['miss'].astype(int)
df_pf1 = df_pf1[df_pf1['miss'] == '0']
df_pf1['folder'] = '../TextSegmentation/Pickle_Files/'

# df_pf2['miss'] = df_pf2[df_pf2['miss'] != 'Incomplete chunk']['miss'].astype(int)
df_pf2 = df_pf2[df_pf2['miss'] == '0']
df_pf2['folder'] = '../TextSegmentation/corrected_10to20/'

# df_pf3['miss'] = df_pf3[df_pf3['miss'] != 'Incomplete chunk']['miss'].astype(int)
df_pf3 = df_pf3[df_pf3['miss'] == '0']
df_pf3['folder'] = '../TextSegmentation/Updated Pickles/'

# %%
badis = []
ids = df_pf1.index
for x in range(len(ids)):
    ix = ids[x]
    f = '%d.p' % df_pf1.loc[ix, 'file']
    p = '../TextSegmentation/Pickle_Files/%s' % f
    skt, dcs = loadSentence(f, p)
    if (x % 100 == 0):
        print(x)
    if(len(skt.chunk) != len(dcs.lemmas)):
        df_pf1.loc[ix, 'miss'] = 'Length Mismatch'
        badis.append(index)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500

# %%
ids = df_pf2.index
for x in range(len(ids)):
    ix = ids[x]
    f = '%d.p' % df_pf2.loc[ix, 'file']
    p = '../TextSegmentation/corrected_10to20/%s' % f
    skt, dcs = loadSentence(f, p)
    if (x % 100 == 0):
        print(x)
    if(len(skt.chunk) != len(dcs.lemmas)):
        df_pf2.loc[ix, 'miss'] = 'Length Mismatch'
        badis.append(index)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900

# %%
ids = df_pf3.index
for x in range(len(ids)):
    ix = ids[x]
    f = '%d.p' % df_pf3.loc[ix, 'file']
    p = '../TextSegmentation/Updated Pickles/%s' % f
    skt, dcs = loadSentence(f, p)
    if (x % 100 == 0):
        print(x)
    if(len(skt.chunk) != len(dcs.lemmas)):
        df_pf3.loc[ix, 'miss'] = 'Length Mismatch'
        badis.append(index)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# 20600
# 20700
# 20800
# 20900
# 21000
# 21100
# 21200
# 21300
# 21400
# 21500
# 21600
# 21700
# 21800
# 21900
# 22000
# 22100
# 22200
# 22300
# 22400
# 22500
# 22600
# 22700
# 22800
# 22900
# 23000
# 23100
# 23200
# 23300
# 23400
# 23500
# 23600
# 23700
# 23800
# 23900
# 24000
# 24100
# 24200
# 24300
# 24400
# 24500
# 24600
# 24700
# 24800
# 24900
# 25000
# 25100
# 25200
# 25300
# 25400
# 25500
# 25600
# 25700
# 25800
# 25900
# 26000
# 26100
# 26200
# 26300
# 26400
# 26500
# 26600
# 26700
# 26800
# 26900
# 27000
# 27100
# 27200
# 27300
# 27400
# 27500
# 27600
# 27700
# 27800
# 27900
# 28000
# 28100
# 28200
# 28300
# 28400
# 28500
# 28600
# 28700
# 28800
# 28900
# 29000
# 29100
# 29200
# 29300
# 29400
# 29500
# 29600
# 29700
# 29800
# 29900
# 30000
# 30100
# 30200
# 30300
# 30400
# 30500
# 30600
# 30700
# 30800
# 30900
# 31000
# 31100
# 31200
# 31300
# 31400
# 31500
# 31600
# 31700
# 31800
# 31900
# 32000
# 32100
# 32200
# 32300
# 32400
# 32500
# 32600
# 32700
# 32800
# 32900
# 33000
# 33100
# 33200
# 33300
# 33400
# 33500
# 33600
# 33700
# 33800
# 33900
# 34000
# 34100
# 34200
# 34300
# 34400
# 34500
# 34600
# 34700

# %%
df_pf1 = df_pf1[df_pf1['miss'] != 'Length Mismatch']
df_pf2 = df_pf2[df_pf2['miss'] != 'Length Mismatch']
df_pf3 = df_pf3[df_pf3['miss'] != 'Length Mismatch']

# %%
frames = [df_pf1, df_pf2, df_pf3]
df_pf = pd.concat(frames)
# %reset_selective df_pf1
# %reset_selective df_pf2
# %reset_selective df_pf3

goodFileDict = {}
for index, row in df_pf.iterrows():
    goodFileDict['%d.p' % row['file']] = '%s%d.p' % (row['folder'], row['file'])
len(goodFileDict)
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  n
# Nothing done.
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  n
# Nothing done.
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  n
# Nothing done.
# 49441

# %%
pickle.dump(goodFileDict, open('mergedGood_v5.p','wb'))

# %%
fs = os.listdir('.temp/July_2_Morning_002/')

allAcc = []
for f in fs:
    td = pickle.load(open('.temp/July_2_Morning_002/' + f, 'rb'))
    [allAcc.append(ac) for ac in td.values()]

# %%
allAcc = np.array(allAcc)

# %%
np.sum(allAcc >= 100)/allAcc.shape[0]

# %%
import pandas as pd

# %%
# Out:
# count    2650.000000
# mean        0.000200
# std         0.001859
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.074117
# Name: 311, dtype: float64

# %%
from SktWsegRWR_utf8 import *
import pickle
import ProbData
from ProbModels import *
import multiprocessing
import math
import json
import pprint
import csv
from utilities import *
from IPython.display import display
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import pandas as pd
# %matplotlib inline
# DO THIS IN PROBDATA_2
mat_lem2cng = json.load(open('../NewData/data1.json', 'r'))
mat_cng2lem = json.load(open('../NewData/data2.json', 'r'))
mat_tup2cng = json.load(open('../NewData/data3.json', 'r'))
mat_tup2lem = json.load(open('../NewData/data4.json', 'r'))
# Out:
# Dataloader Started[Prob]...
# Dataloader Finished[Prob]...

# %%
for key in list(mat_lem2cng.keys()):
    mat_lem2cng[rom_slp(key)] = mat_lem2cng.pop(key)
print('Doing')
for key, innerdict in mat_cng2lem.items():
    for lem in list(innerdict.keys()):
        mat_cng2lem[key][rom_slp(lem)] = mat_cng2lem[key].pop(lem)
print('Doing')
for key in list(mat_tup2lem.keys()):
    innerdict = mat_tup2lem[key]
    for lem in list(innerdict.keys()):
        mat_tup2lem[key][rom_slp(lem)] = mat_tup2lem[key].pop(lem)
    mat_tup2lem[rom_slp(key)] = mat_tup2lem.pop(key)
print('Doing')
for key in list(mat_tup2cng.keys()):
    mat_tup2cng[rom_slp(key)] = mat_tup2cng.pop(key)
print('Doing')
# Out:
# Doing
# Doing
# Doing
# Doing

# %%
pickle.dump(mat_cng2lem, open('../NewData/mat_cng2lem.p','wb'))
pickle.dump(mat_lem2cng, open('../NewData/mat_lem2cng.p','wb'))
pickle.dump(mat_tup2cng, open('../NewData/mat_tup2cng.p','wb'))
pickle.dump(mat_tup2lem, open('../NewData/mat_tup2lem.p','wb'))

# %%
display(mat_tup2lem['kataka_41'])
# Out:
# {'SaNKa': ['192989.p'],
#  'Sukti': ['192989.p'],
#  'ca': ['192989.p'],
#  'drAkzA': ['192989.p'],
#  'maDu': ['192989.p'],
#  'maDuka': ['192989.p']}

# %%
df_pcrw = pd.read_csv('pcrw_01.csv',
                      usecols=['f', 'ln_lemma', 'rn_lemma', 'ln_cng', 'rn_cng', '111', '112', '113', '122', '123', '131', '132', '211', '212', '213', '222', '223', '231', '232', '311', '312', '322', '400', '500', '600', '700', '800', 'flag'])

# %%
df_pcrw.shape
# Out:
# (5085594, 28)

# %%
df_pcrw = df_pcrw.drop(df_pcrw[np.isnan(df_pcrw.ln_cng) | np.isnan(df_pcrw.rn_cng)].index) # Add

# %%
df_pcrw.ln_cng = df_pcrw.ln_cng.astype(int) # Add
df_pcrw.rn_cng = df_pcrw.rn_cng.astype(int) # Add

# %%
df_pcrw
# Out:
#                  f ln_lemma rn_lemma  ln_cng  rn_cng       111       112  \
# 2        123274.p2   arjuna     vaDa     149      36  0.000223  0.000055
# 3        123274.p2   arjuna     vaDa     151      36  0.000223  0.000055
# 4        123274.p2   arjuna     vaDa     149      75  0.000223  0.000034
# 5        123274.p2   arjuna     vaDa     151      75  0.000223  0.000034
# 6        123274.p2   arjuna     vaDa     149      76  0.000223  0.000127
# 7        123274.p2   arjuna     vaDa     151      76  0.000223  0.000127
# 8        123274.p2   arjuna     vaDa     149      49  0.000223  0.003542
# 9        123274.p2   arjuna     vaDa     151      49  0.000223  0.003542
# 10       123274.p2   arjuna     vaDa     149      51  0.000223  0.000011
# 11       123274.p2   arjuna     vaDa     151      51  0.000223  0.000011
# 12       123274.p2   arjuna     vaDa     149      56  0.000223  0.000000
# 13       123274.p2   arjuna     vaDa     151      56  0.000223  0.000000
# 14       123274.p2   arjuna     vaDa     149      50  0.000223  0.000653
# 15       123274.p2   arjuna     vaDa     151      50  0.000223  0.000653
# 16       123274.p2   arjuna     vaDa     149      55  0.000223  0.000000
# 17       123274.p2   arjuna     vaDa     151      55  0.000223  0.000000
# 18       123274.p2   arjuna    krUra     149      70  0.000028  0.005329
# 19       123274.p2   arjuna    krUra     151      70  0.000028  0.005329
# 20       123274.p2     vaDa    krUra      35      70  0.000068  0.012844
# 21       123274.p2     vaDa    krUra      36      70  0.000068  0.012844
# 22       123274.p2     vaDa    krUra      75      70  0.000068  0.012844
# 23       123274.p2     vaDa    krUra      76      70  0.000068  0.012844
# 24       123274.p2     vaDa    krUra      49      70  0.000068  0.012844
# 25       123274.p2     vaDa    krUra      51      70  0.000068  0.012844
# 26       123274.p2     vaDa    krUra      56      70  0.000068  0.012844
# 27       123274.p2     vaDa    krUra      50      70  0.000068  0.012844
# 28       123274.p2     vaDa    krUra      55      70  0.000068  0.012844
# 29       123274.p2   arjuna       kf     149     -43  0.000000  0.000000
# 30       123274.p2   arjuna       kf     151     -43  0.000000  0.000000
# 31       123274.p2     vaDa       kf      35     -43  0.000000  0.000000
# ...            ...      ...      ...     ...     ...       ...       ...
# 5085564  245739.p2     tvad  nandana     112      51  0.000023  0.000006
# 5085565  245739.p2    pARqu  nandana       3      51  0.000013  0.000003
# 5085566  245739.p2    pARqu  nandana      31      51  0.000013  0.000003
# 5085567  245739.p2    pARqu  nandana      71      51  0.000013  0.000003
# 5085568  245739.p2   kumAra     nand       3     -32  0.000007  0.000408
# 5085569  245739.p2       ad     nand      31     -32  0.000020  0.000836
# 5085570  245739.p2       ad     nand      29     -32  0.000020  0.000836
# 5085571  245739.p2       ad     nand      30     -32  0.000020  0.000836
0.000000  0.000000  0.0  0.0  0.0  0.0     1
# 20       0.000000  0.000000  0.0  0.0  0.0  0.0     1
# 21       0.000000  0.000000  0.0  0.0  0.0  0.0     1
# 22       0.000000  0.000000  0.0  0.0  0.0  0.0     1
# 23       0.000000  0.000000  0.0  0.0  0.0  0.0     1
# 24       0.000000  0.000000  0.0  0.0  0.0  0.0     1
# 25       0.000000  0.000000  0.0  0.0  0.0  0.0     1
# 26       0.000000  0.000000  0.0  0.0  0.0  0.0     1
# 27       0.000000  0.000000  0.0  0.0  0.0  0.0     1
# 28       0.000000  0.000000  0.0  0.0  0.0  0.0     1
# 29       0.000000  0.000000  0.0  0.0  0.0  0.0     1
# 30       0.000000  0.000000  0.0  0.0  0.0  0.0     1
# 31       0.000000  0.000000  0.0  0.0  0.0  0.0     1
# ...           ...       ...  ...  ...  ...  ...   ...
# 5085564  0.000006  0.000000  0.0  0.0  0.0  0.0     0
# 5085565  0.000017  0.000000  0.0  0.0  0.0  0.0     1
# 5085566  0.000011  0.025424  0.0  0.0  0.0  0.0     1
# 5085567  0.000027  0.025424  0.0  0.0  0.0  0.0     1
# 5085568  0.003658  0.000000  0.0  0.0  0.0  0.0     0
# 5085569  0.000000  0.000000  0.0  0.0  0.0  0.0     0
# 5085570  0.000000  0.000000  0.0  0.0  0.0  0.0     0
# 5085571  0.000000  0.000000  0.0  0.0  0.0  0.0     0
# 5085572  0.000000  0.000000  0.0  0.0  0.0  0.0     0
# 5085573  0.000000  0.000000  0.0  0.0  0.0  0.0     0
# 5085574  0.001889  0.000000  0.0  0.0  0.0  0.0     0
# 5085575  0.006077  0.000000  0.0  0.0  0.0  0.0     0
# 5085576  0.002188  0.000000  0.0  0.0  0.0  0.0     0
# 5085577  0.001456  0.000000  0.0  0.0  0.0  0.0     0
# 5085578  0.003403  0.000000  0.0  0.0  0.0  0.0     0
# 5085579  0.002387  0.000000  0.0  0.0  0.0  0.0     0
# 5085580  0.001095  0.000000  0.0  0.0  0.0  0.0     0
# 5085581  0.002220  0.000000  0.0  0.0  0.0  0.0     0
# 5085582  0.000000  0.000000  0.0  0.0  0.0  0.0     0
# 5085583  0.003329  0.000000  0.0  0.0  0.0  0.0     0
# 5085584  0.009115  0.000000  0.0  0.0  0.0  0.0     0
# 5085585  0.007596  0.000000  0.0  0.0  0.0  0.0     0
# 5085586  0.003146  0.000000  0.0  0.0  0.0  0.0     0
# 5085587  0.003161  0.000000  0.0  0.0  0.0  0.0     0
# 5085588  0.001577  0.000000  0.0  0.0  0.0  0.0     0
# 5085589  0.000739  0.000000  0.0  0.0  0.0  0.0     0
# 5085590  0.002165  0.000000  0.0  0.0  0.0  0.0     0
# 5085591  0.001036  0.000000  0.0  0.0  0.0  0.0     0
# 5085592  0.003646  0.000000  0.0  0.0  0.0  0.0     0
# 5085593  0.002449  0.000000  0.0  0.0  0.0  0.0     0
#
# [5085323 rows x 28 columns]

# %%
scores = np.random.random(size=(10,5))
scores[:, 1] = 1
scores[:, 2] = 0.5
scores
# Out:
# array([[ 0.16242274,  1.        ,  0.5       ,  0.92007169,  0.48619376],
#        [ 0.22942637,  1.        ,  0.5       ,  0.70247483,  0.70509047],
#        [ 0.6336042 ,  1.        ,  0.5       ,  0.67495017,  0.10189551],
#        [ 0.09962673,  1.        ,  0.5       ,  0.33786264,  0.21711227],
#        [ 0.35409389,  1.        ,  0.5       ,  0.40859989,  0.05430687],
#        [ 0.0308764 ,  1.        ,  0.5       ,  0.2932863 ,  0.29662927],
#        [ 0.78166938,  1.        ,  0.5       ,  0.44021505,  0.17041417],
#        [ 0.41160622,  1.        ,  0.5       ,  0.11224224,  0.67134119],
#        [ 0.71753933,  1.        ,  0.5       ,  0.34895825,  0.0952816 ],
#        [ 0.88294228,  1.        ,  0.5       ,  0.69033836,  0.82928214]])

# %%
goodWeights = [0,1,1,0,0]

# %%
for c in range(scores.shape[1]):
    scores[:, c] *= goodWeights[c]

# %%
np.sum(scores, axis = 1)
# Out:
# array([ 1.5,  1.5,  1.5,  1.5,  1.5,  1.5,  1.5,  1.5,  1.5,  1.5])
